# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-s_9hu7w3
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-s_9hu7w3
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# ...

# %%
# %run "/content/drive/My Drive/VAE_vs_Others/ddpm_clip_fashionmnist_per_class.py"
# Out:
# <generator object Module.parameters at 0x7bbccc11d700>
# ...
# Epoch 26:  88%|████████▊ | 28/32 [00:10<00:01,  2.78it/s, loss=0.0742]

# %%
# %run "/content/drive/My Drive/VAE_vs_Others/clip-guided.py"
# Out:
# ...
# Epoch 21/21: 100%|██████████| 32/32 [00:11<00:00,  2.75it/s, loss=0.0983]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Generated: cotton crewneck T‑shirt → /content/drive/My Drive/VAE_vs_Others/guided_ddpm_per_class_output/cotton_crewneck_T‑shirt.png
# Generated: tailored trousers → /content/drive/My Drive/VAE_vs_Others/guided_ddpm_per_class_output/tailored_trousers.png
# Generated: thick wool pullover sweater → /content/drive/My Drive/VAE_vs_Others/guided_ddpm_per_class_output/thick_wool_pullover_sweater.png
# Generated: light summer dress → /content/drive/My Drive/VAE_vs_Others/guided_ddpm_per_class_output/light_summer_dress.png
# Generated: button‑front long overcoat → /content/drive/My Drive/VAE_vs_Others/guided_ddpm_per_class_output/button‑front_long_overcoat.png
# Generated: leather sandal → /content/drive/My Drive/VAE_vs_Others/guided_ddpm_per_class_output/leather_sandal.png
# ...
